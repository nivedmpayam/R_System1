# %%
# !pip install -qq convokit
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.2/183.2 kB 2.8 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 4.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 235.5/235.5 kB 6.3 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 677.1/677.1 kB 7.2 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 300.4/300.4 kB 12.8 MB/s eta 0:00:00
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 175.4/175.4 kB 15.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.1/53.1 kB 4.4 MB/s eta 0:00:00
#   Building wheel for convokit (pyproject.toml) ... done
#   Building wheel for emoji (setup.py) ... done

# %%
# !pip install -qq scikit-surprise
# Out:
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 772.0/772.0 kB 6.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
#   Building wheel for scikit-surprise (setup.py) ... done

# %%
import pandas as pd
import numpy as np
from surprise import Dataset, Reader, SVD
from surprise.model_selection import train_test_split
from surprise import accuracy
import convokit

# %%
# Load the Cornell Movie Dialogs Corpus
corpus = convokit.Corpus(filename=convokit.download("movie-corpus"))
# Out:
# Downloading movie-corpus to /root/.convokit/downloads/movie-corpus
# Downloading movie-corpus from http://zissou.infosci.cornell.edu/convokit/datasets/movie-corpus/movie-corpus.zip (40.9MB)... Done
# No configuration file found at /root/.convokit/config.yml; writing with contents:
# # Default Backend Parameters
# db_host: localhost:27017
# data_directory: ~/.convokit/saved-corpora
# default_backend: mem

# %%
# Display basic statistics
print("Number of conversations:", len(corpus.conversations))
print("Number of users:", len(corpus.speakers))
print("Number of utterances:", len(corpus.utterances))
# Out:
# Number of conversations: 83097
# Number of users: 9035
# Number of utterances: 304713

# %%
# Display information about conversations
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)
    print("Conversation ID:", convo_id)
    print("Metadata:", convo.meta)
    print("Number of utterances in conversation:", len(convo.get_utterance_ids()))
    print()
# Out:
# Streaming output truncated to the last 5000 lines.
# Conversation ID: L343914
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L343904
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L343898
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L343894
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343892
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343889
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343883
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343872
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L343869
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343866
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343862
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343857
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343853
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343844
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343842
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343838
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343821
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 15
#
# Conversation ID: L343816
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L343811
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L343806
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343801
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L343798
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343794
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L343790
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343788
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343786
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343765
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L343763
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343761
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343758
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343723
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L343720
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343717
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343714
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343710
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343708
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343699
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L343695
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343692
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343685
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343683
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343681
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343677
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L343580
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L343576
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L343753
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343746
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L343742
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343779
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343775
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343770
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343735
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343733
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343731
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343605
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343600
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343590
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L343587
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L343544
# Metadata: ConvoKitMeta({'movie_idx': 'm116', 'movie_name': 'leaving las vegas', 'release_year': '1995', 'rating': '7.60', 'votes': '42919', 'genre': "['drama', 'romance']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L344771
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344765
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L345515
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L345154
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L345152
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345147
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345142
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L345503
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L345432
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345375
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345246
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345242
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345238
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345236
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345229
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345160
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345197
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L345585
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345579
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345572
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345570
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345565
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345563
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345556
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345548
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L345087
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345083
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345531
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345525
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345477
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345473
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345470
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345465
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L345453
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345428
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345256
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345254
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345220
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345438
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345208
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345204
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345522
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345354
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345350
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345104
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L344877
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L344873
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L344870
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345496
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345455
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L345179
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345174
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L345164
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345093
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345074
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345072
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344949
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344945
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344937
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L344932
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L344929
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345222
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L345622
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345617
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345483
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345461
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345388
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L345383
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345380
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345055
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344968
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344917
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345601
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345404
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345400
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344995
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344981
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L344796
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344787
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L344784
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L344749
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344739
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344730
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344667
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344660
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L344650
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344646
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345630
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345624
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L345590
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345492
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345488
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345486
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345430
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345423
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345342
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345336
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L345332
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345326
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L345322
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345316
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L345305
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345296
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345294
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345288
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345285
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345275
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 10
#
# Conversation ID: L345215
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345039
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344910
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344904
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344902
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344897
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L344894
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345599
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345397
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345394
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344988
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L344807
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344777
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344736
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L344732
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344726
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L344648
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345139
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345130
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345125
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345123
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345067
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345062
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L344962
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344957
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L344836
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L344833
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345612
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L345608
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345436
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345426
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345266
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345115
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L345020
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L345013
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L344921
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344914
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344912
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344863
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L344857
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L344708
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L344705
# Metadata: ConvoKitMeta({'movie_idx': 'm117', 'movie_name': 'legally blonde', 'release_year': '2001', 'rating': '6.20', 'votes': '44558', 'genre': "['comedy']"})
# ...
# Number of utterances in conversation: 6
#
# Conversation ID: L666019
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665957
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665904
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665896
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665891
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665873
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665868
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665865
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665861
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665840
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665802
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665798
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665775
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665755
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665748
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L665691
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665676
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665663
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665658
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665636
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665627
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 7
#
# Conversation ID: L665623
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665615
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 8
#
# Conversation ID: L665564
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665558
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665552
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665548
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666168
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666166
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666160
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666158
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666151
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666149
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665949
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665900
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665885
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665694
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L665651
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665994
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L665992
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L665987
# Metadata: ConvoKitMeta({'movie_idx': 'm615', 'movie_name': 'young frankenstein', 'release_year': '1974', 'rating': '8.00', 'votes': '57618', 'genre': "['comedy', 'sci-fi']"})
# Number of utterances in conversation: 5
#
# Conversation ID: L666462
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666365
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666361
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666503
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666388
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 11
#
# Conversation ID: L666487
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666483
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666480
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666357
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666249
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666246
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666546
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666485
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666460
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666383
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666251
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666497
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 6
#
# Conversation ID: L666575
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2
#
# Conversation ID: L666324
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666262
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666520
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 3
#
# Conversation ID: L666369
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 4
#
# Conversation ID: L666256
# Metadata: ConvoKitMeta({'movie_idx': 'm616', 'movie_name': 'zulu dawn', 'release_year': '1979', 'rating': '6.40', 'votes': '1911', 'genre': "['action', 'adventure', 'drama', 'history', 'war']"})
# Number of utterances in conversation: 2

# %%
# Create empty lists to store data
conversation_ids = []
movie_indices = []
movie_names = []
release_years = []
ratings = []
votes = []
genres = []
num_utterances = []

# Loop through conversations and extract data
for convo_id in corpus.get_conversation_ids():
    convo = corpus.get_conversation(convo_id)

    # Extract metadata from ConvoKitMeta object
    metadata = convo.meta

    # Append data to respective lists
    conversation_ids.append(convo_id)
    movie_indices.append(metadata['movie_idx'])
    movie_names.append(metadata['movie_name'])
    release_years.append(metadata['release_year'])
    ratings.append(metadata['rating'])
    votes.append(metadata['votes'])
    genres.append(metadata['genre'])
    num_utterances.append(len(convo.get_utterance_ids()))

# Create a DataFrame from the lists
data = {
    'Conversation ID': conversation_ids,
    'Movie Index': movie_indices,
    'Movie Name': movie_names,
    'Rating': ratings,
}

dt = pd.DataFrame(data)

# %%
dt
# Out:
#       Conversation ID Movie Index                  Movie Name Rating
# 0               L1044          m0  10 things i hate about you   6.90
# 1                L984          m0  10 things i hate about you   6.90
# 2                L924          m0  10 things i hate about you   6.90
# 3                L870          m0  10 things i hate about you   6.90
# 4                L866          m0  10 things i hate about you   6.90
# ...               ...         ...                         ...    ...
# 83092         L666324        m616                   zulu dawn   6.40
# 83093         L666262        m616                   zulu dawn   6.40
# 83094         L666520        m616                   zulu dawn   6.40
# 83095         L666369        m616                   zulu dawn   6.40
# 83096         L666256        m616                   zulu dawn   6.40
#
# [83097 rows x 4 columns]

# %%
# Create a Reader object specifying the rating scale
reader = Reader(rating_scale=(1, 10))

# %%
# Load the dataset into Surprise format
data = dt[['Conversation ID','Movie Name','Rating']]
data = Dataset.load_from_df(data, reader)

# Split the data into training and testing sets (80% train, 20% test)
trainset, testset = train_test_split(data, test_size=0.2, random_state=42)

# Create and train the SVD recommendation model
model = SVD()
model.fit(trainset)

# Evaluate the model on the testing data (calculate RMSE)
predictions = model.test(testset)
rmse = accuracy.rmse(predictions)
# Out:
# RMSE: 0.0638

# %%
# Generate recommendations for a specific user (e.g., user_id='L236416')
user_id = 'L36547'
user_movies = dt[dt['Conversation ID'] == user_id]['Movie Name'].unique()

# Create a list of unrated movies for the user
all_movies = dt['Movie Name'].unique()
unrated_movies = np.setdiff1d(all_movies, user_movies)

# Generate predictions for unrated movies
user_recommendations = []
for movie_id in unrated_movies:
    predicted_rating = model.predict(user_id, movie_id).est
    user_recommendations.append((movie_id, predicted_rating))

    # Sort recommendations by predicted rating (highest first)
user_recommendations.sort(key=lambda x: x[1], reverse=True)

# %%
# Display the top n recommendations
top_n = 3
print(f'Top {top_n} recommendations for user {user_id}:')
for movie_id, predicted_rating in user_recommendations[:top_n]:
    print(f'Movie ID: {movie_id}, Predicted Rating: {predicted_rating:.2f}')
# Out:
# Top 3 recommendations for user L36547:
# Movie ID: neuromancer, Predicted Rating: 9.17
# Movie ID: the godfather, Predicted Rating: 9.06
# Movie ID: one flew over the cuckoo's nest, Predicted Rating: 8.89
